# %%
# Install some library
# pip install tweepy
# pip install configparser
# pip install pymongo
# pip install dnspython
# pip install pymongo[srv]
# pip install pymongo[ocsp]

# %%
# Import library
import tweepy
import pandas as pd
import configparser
import pymongo
from pymongo import MongoClient
import json
from datetime import date
import csv
from time import sleep

# %%
# Function to stream data
def twitter_collection_data(number_of_tweets, number_of_times):
    #Read credentials from config file
    config = configparser.ConfigParser()  #creating a config parser instance
    config.read('config.ini')

    api_key = config['twitter']['api_key']
    api_key_secret = config['twitter']['api_key_secret']

    access_token = config['twitter']['access_token']
    access_token_secret = config['twitter']['access_token_secret']

    #Authenticate to Twitter API
    auth = tweepy.OAuthHandler(api_key, api_key_secret)
    auth.set_access_token(access_token, access_token_secret)

    # MongoDB connection 

    #Ambi Mongo DB account
    # myclient = pymongo.MongoClient("mongodb://AmbikaNair:MongoDB@cluster0.wjpum.mongodb.net/BDP-2&retryWrites=true&w=majority?ssl=true&ssl_cert_reqs=CERT_NONE")

    # mydb = myclient["BDP-2"] #Database

    # mycol = mydb["TweetsVersion1"] 

    #Quyen MongoDB Account
    # myclient = pymongo.MongoClient("mongodb+srv://HAAQ:BigDataProgramming2@cluster0.p7f2o8h.mongodb.net/?retryWrites=true&w=majority")

    # mydb = myclient["BD2"] #Database

    # mycol = mydb["Cluster0"]

    # Get today 
    today = date.today()
    file_name = ('Twitter_realtime_data_'+ str(today))
    
    #Create API
    api = tweepy.API(auth, wait_on_rate_limit=True)

    tweets = []
    time = []
    user = []

    # Streaming data
    for i in range(number_of_times): 
        for tweet in tweepy.Cursor(api.home_timeline, tweet_mode = "extended").items(number_of_tweets):

            tweets.append(tweet.full_text)
            time.append(tweet.created_at)
            user.append(tweet.user.screen_name)
            
            # Code sleeping to avoid over limitation
            async def main():
                await asyncio.sleep(900)

    # Dictionary format to insert to Mongo
    title_list = ["Tweets", "Created At", "User"]
    tweets_list = [tweets, time, user]
    data_dictionary = dict(zip(title_list, tweets_list))

    # Insert into database
    # mycol.insert_one(data_dictionary)
    df = pd.DataFrame({'Tweets': tweets, 'Created At': time, 'User': user})
    df.to_csv(file_name +'.csv')

    return df

# %%
twitter_collection_data(10,2)
# Out:
#                                                Tweets          Created At  \
# 0   The clearest photo of Mercury ever taken\nCred... 2022-07-17 11:45:00
# 1   First X-rays from Uranus Discovered\nSource:ht... 2022-07-17 10:58:11
# 2   Jupiter from the James Webb Space Telescope (2... 2022-07-17 07:29:31
# 3   NASA  This image depicts a full view of the Ea... 2022-07-17 03:43:00
# 4   Europa above Jupiter captured by Voyager\nCred... 2022-07-17 02:41:00
# 5   The Sun in X-rays from NuSTAR\nImage Credit: N... 2022-07-17 00:39:00
# 6   NASA   Saturn’s moon Enceladus. Cassini spacec... 2022-07-16 23:36:00
# 7   Hubble vs JWST First Image Comparison https://... 2022-07-16 22:33:00
# 8   In space, there's no up or down\nCredit: NASA ... 2022-07-16 21:53:00
# 9   "Dare I say Jupiter is more beautiful than ear... 2022-07-16 20:45:04
# 10  The clearest photo of Mercury ever taken\nCred... 2022-07-17 11:45:00
# 11  First X-rays from Uranus Discovered\nSource:ht... 2022-07-17 10:58:11
# 12  Jupiter from the James Webb Space Telescope (2... 2022-07-17 07:29:31
# 13  NASA  This image depicts a full view of the Ea... 2022-07-17 03:43:00
# 14  Europa above Jupiter captured by Voyager\nCred... 2022-07-17 02:41:00
# 15  The Sun in X-rays from NuSTAR\nImage Credit: N... 2022-07-17 00:39:00
# 16  NASA   Saturn’s moon Enceladus. Cassini spacec... 2022-07-16 23:36:00
# 17  Hubble vs JWST First Image Comparison https://... 2022-07-16 22:33:00
# 18  In space, there's no up or down\nCredit: NASA ... 2022-07-16 21:53:00
# 19  "Dare I say Jupiter is more beautiful than ear... 2022-07-16 20:45:04
#
#               User
# 0   konstructivizm
# 1   konstructivizm
# 2   konstructivizm
# 3   konstructivizm
# 4   konstructivizm
# 5   konstructivizm
# 6   konstructivizm
# 7   konstructivizm
# 8   konstructivizm
# 9   konstructivizm
# 10  konstructivizm
# 11  konstructivizm
# 12  konstructivizm
# 13  konstructivizm
# 14  konstructivizm
# 15  konstructivizm
# 16  konstructivizm
# 17  konstructivizm
# 18  konstructivizm
# 19  konstructivizm
